# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
np.random.rand(10)
# Out:
# array([0.39279407, 0.42862518, 0.68979516, 0.16693637, 0.32736696,
#        0.90263628, 0.85765332, 0.68638595, 0.7010039 , 0.53812494])

# %%
x = np.linspace(-50,50,11)
x_r = x + np.random.rand(11) * 10
y = 2 * np.power(x_r,3) + 5 * np.power(x_r, 2) + 4 * x_r + 3
plt.scatter(x,y)

plt.plot([x[0],x[-1]], [y[0],y[-1]])

# %%
x.shape
# Out:
# (7,)

# %%
x = np.linspace(-3,2, 20)
y = 1 * np.power(x, 3) + 2 * np.power(x,2) - 3 * x + (np.random.rand(x.shape[0])-0.5) * 5
x = x+3
plt.scatter(x,y)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# MatPlotlib
import matplotlib.pyplot as plt
from matplotlib import pylab

# Scientific libraries
import numpy as np

#points = np.array([(1, 1), (2, 4), (3, 1), (9, 3)])

# get x and y vectors
#x = points[:,0]
#y = points[:,1]
for n in [1, 3, 13]:
    # calculate polynomial
    z = np.polyfit(x, y, n)
    f = np.poly1d(z)
    print (f)
    # calculate new x's and y's
    x_new = np.linspace(x[0], x[-1], 50)
    y_new = f(x_new)


    plt.plot(x,y,'o', x_new, y_new)
    #pylab.title('Polynomial Fit with Matplotlib')
    ax = plt.gca()
    #ax.axes.xaxis.set_ticklabels([])
    #ax.axes.yaxis.set_ticklabels([])
    #ax.set_axis_bgcolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    #py.plot_mpl(fig, filename='polynomial-Fit-with-matplotlib')
    plt.ylim([-2,10])
    #plt.axis('off')
    plt.tick_params(axis='both', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='off', labelright='off', labelbottom='off')
    plt.savefig('figs/mdl_{}.eps'.format(n), dpi=400, bbox_inches='tight', pad_inches=0.0)
    plt.show()
# Out:
#
# -0.08956 x + 3.154
#        3         2
# 1.098 x - 7.873 x + 14.14 x - 1.225
#           13           12          11         10         9         8
# 0.001223 x  - 0.05324 x  + 0.9954 x  - 10.63 x  + 72.32 x - 330.1 x
#          7        6        5        4        3         2
#  + 1035 x - 2235 x + 3294 x - 3216 x + 1970 x - 681.5 x + 110.4 x - 1.849
